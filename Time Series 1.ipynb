# %% [markdown]
# # DataSet Not accessable

# %% [markdown]
# https://datamarket.com/data/set/22r0/sales-of-shampoo-over-a-three-year-period#!ds

# %% [markdown]
# ![image.png](attachment:image.png)
